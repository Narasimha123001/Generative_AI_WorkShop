# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = [
    "I love programming in Python.",
    "Python is a great programming language.",
    "I enjoy learning about data science."
]

# %% [markdown]
# # Initialize TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer()

# %% [markdown]
# # Fit and transform the corpus

# %%
X_tfidf = tfidf_vectorizer.fit_transform(corpus)

# %% [markdown]
# # Get the feature names (unique words)

# %%
feature_names_tfidf = tfidf_vectorizer.get_feature_names_out()
print("Feature Names (TF-IDF):", feature_names_tfidf)
# Out:
# Feature Names (TF-IDF): ['about' 'data' 'enjoy' 'great' 'in' 'is' 'language' 'learning' 'love'
#  'programming' 'python' 'science']

# %%
print("TF-IDF Representation:\n", X_tfidf.toarray())
# Out:
# TF-IDF Representation:
#  [[0.         0.         0.         0.         0.5628291  0.
#   0.         0.         0.5628291  0.42804604 0.42804604 0.        ]
#  [0.         0.         0.         0.49047908 0.         0.49047908
#   0.49047908 0.         0.         0.37302199 0.37302199 0.        ]
#  [0.4472136  0.4472136  0.4472136  0.         0.         0.
#   0.         0.4472136  0.         0.         0.         0.4472136 ]]
