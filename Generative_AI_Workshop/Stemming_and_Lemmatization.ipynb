# %% [markdown]
# # Import necessary libraries

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

nltk.download('punkt')  # For tokenizing sentences and words
nltk.download('wordnet')  # For lemmatization
nltk.download('averaged_perceptron_tagger')  # For POS tagging (optional for advanced lemmatization)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# # Sample text

# %%
text = "I saw this movie in the theatre and it was a terrible movie."

# %% [markdown]
# # Tokenize the text

# %%
words = word_tokenize(text)

print("original Words",words)
# Out:
# original Words ['I', 'saw', 'this', 'movie', 'in', 'the', 'theatre', 'and', 'it', 'was', 'a', 'terrible', 'movie', '.']

# %% [markdown]
# # Initialize the Porter Stemmer

# %%
stemmer = PorterStemmer()

# %% [markdown]
# # Apply stemming

# %%
stemmed_words = [stemmer.stem(word) for word in words]
print("Stemmed Words:", stemmed_words)
# Out:
# Stemmed Words: ['i', 'saw', 'thi', 'movi', 'in', 'the', 'theatr', 'and', 'it', 'wa', 'a', 'terribl', 'movi', '.']

# %% [markdown]
# # Initialize the WordNet Lemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# # Apply lemmatization

# %%
lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
print("Lemmatized Words:", lemmatized_words)

# POS Tagging
pos_tags = nltk.pos_tag(words)
print("POS Tags:", pos_tags)
# Out:
# Lemmatized Words: ['I', 'saw', 'this', 'movie', 'in', 'the', 'theatre', 'and', 'it', 'wa', 'a', 'terrible', 'movie', '.']
# POS Tags: [('I', 'PRP'), ('saw', 'VBD'), ('this', 'DT'), ('movie', 'NN'), ('in', 'IN'), ('the', 'DT'), ('theatre', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('terrible', 'JJ'), ('movie', 'NN'), ('.', '.')]
